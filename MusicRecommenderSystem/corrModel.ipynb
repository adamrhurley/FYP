# %% [markdown]
# <a href="https://colab.research.google.com/github/adamrhurley/FYP/blob/main/MusicRecommenderSystem/corrModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0ca6d0d9-f937-4abf-86ac-e9e111fba164" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ca6d0d9-f937-4abf-86ac-e9e111fba164">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving artists.dat to artists.dat
# Saving user_artists.dat to user_artists.dat

# %%
import io
numPlays = pd.read_csv(io.BytesIO(uploaded['user_artists.dat']), sep='\t')
artists = pd.read_csv(io.BytesIO(uploaded['artists.dat']), sep='\t',usecols=['id','name'])

# %%
data = pd.merge(
  artists, numPlays,
  how="inner",
  left_on="id",
  right_on="artistID"
)

# %%
data = data.rename(columns={"weight": "plays"})

# %%
data.head()
# Out:
#    id             name  userID  artistID  plays
# 0   1     MALICE MIZER      34         1    212
# 1   1     MALICE MIZER     274         1    483
# 2   1     MALICE MIZER     785         1     76
# 3   2  Diary of Dreams     135         2   1021
# 4   2  Diary of Dreams     257         2    152

# %%
user_artist_plays = data.pivot_table(index='userID', columns='name', values='plays')

# %%
user_artist_plays.head()
# Out:
# name    !!!  !DISTAIN  !deladap  #####  ...  ＶａｎｅｓｓＡ  ｂｏｏｇｉｅｍａｎ  ｂｏｒｎ  ｍａｃｈｉｎｅ
# userID                                  ...
# 2       NaN       NaN       NaN    NaN  ...      NaN        NaN   NaN      NaN
# 3       NaN       NaN       NaN    NaN  ...      NaN        NaN   NaN      NaN
# 4       NaN       NaN       NaN    NaN  ...      NaN        NaN   NaN      NaN
# 5       NaN       NaN       NaN    NaN  ...      NaN        NaN   NaN      NaN
# 6       NaN       NaN       NaN    NaN  ...      NaN        NaN   NaN      NaN
#
# [5 rows x 17632 columns]

# %%
print(user_artist_plays.corr()['Martin Solveig'].sort_values(ascending=False).iloc[:20])
# Out:
# name
# The White Stripes    1.000000
# Lady Gaga            1.000000
# Armand van Helden    1.000000
# Crystal Castles      1.000000
# David Guetta         1.000000
# The Beatles          1.000000
# Kanye West           1.000000
# Martin Solveig       1.000000
# Muse                 1.000000
# Pendulum             1.000000
# Arctic Monkeys       1.000000
# Daft Punk            0.999838
# MGMT                 0.999361
# Radiohead            0.991678
# Justice              0.976897
# Green Day           -1.000000
# Depeche Mode        -1.000000
# !!!                       NaN
# !DISTAIN                  NaN
# !deladap                  NaN
# Name: Martin Solveig, dtype: float64
